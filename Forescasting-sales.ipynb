# %%
# 3 - Importar a tabela de dados

import pandas as pd
df = pd.read_excel(r"MachineOrders03.xlsx")

display(df)
# Out:
#                                  Company  Custno    Invdate  year yearmonth  \
# 0                FOOD MACHINE AUTOMATION     294 2016-06-26  2016   2016-06
# 1     SHANGHAI UNITECH FOOD MACHINERY CO    2584 2016-06-27  2016   2016-06
# 2     SHANGHAI UNITECH FOOD MACHINERY CO    2584 2016-06-27  2016   2016-06
# 3                BOYENS BACKSERVICE GMBH    1258 2016-06-28  2016   2016-06
# 4                BOYENS BACKSERVICE GMBH    1258 2016-06-28  2016   2016-06
# ...                                  ...     ...        ...   ...       ...
# 6197                   BOSTON BAKING INC    2114 2022-01-20  2022   2022-01
# 6198                   BOSTON BAKING INC    2114 2022-01-20  2022   2022-01
# 6199                   BOSTON BAKING INC    2114 2022-01-20  2022   2022-01
# 6200             BOYENS BACKSERVICE GMBH    1258 2022-01-20  2022   2022-01
# 6201             BOYENS BACKSERVICE GMBH    1258 2022-01-20  2022   2022-01
#
#       Invoice      SONO                     Partno  \
# ...

# %%
df.dtypes

#df.columns  
#list(df.columns)
# Out:
# Company                  object
# Custno                    int64
# Invdate          datetime64[ns]
# year                      int64
# yearmonth                object
# Invoice                   int64
# SONO                    float64
# Partno                   object
# descript                 object
# prodcl                   object
# Product Class            object
# soldby                   object
# txnprice                float64
# Cur                      object
# Rate                    float64
# totprice                float64
# dtype: object

# %%
print(df.isna().sum())     # a coluna sono tem 2 celulas vazias e a descript 10
# Out:
# Company           0
# Custno            0
# Invdate           0
# year              0
# yearmonth         0
# Invoice           0
# SONO              2
# Partno            0
# descript         10
# prodcl            0
# Product Class     0
# soldby            0
# txnprice          0
# Cur               0
# Rate              0
# totprice          0
# dtype: int64
